# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
video = cv2.VideoCapture('./video/1.mp4')
#ret, image = video.read()

# %%
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

length, width, height, fps
# Out:
# (431, 736, 1280, 30.0)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB));

# %%
# 사진 추출

#video = cv2.VideoCapture('./video/test.mp4')

count = 0
num = 10
extractFrame = int(length / 10)

while(video.isOpened()):
    ret, image = video.read()
    if not ret: break
    if(int(video.get(1)) % extractFrame == 0): #앞서 불러온 fps 값을 사용하여 1초마다 추출
        
        cv2.imwrite("./result/" + f"{count}.jpg", image)
        print('Saved frame :', str(int(video.get(1))))
        count += 1
        
#video.release()
# Out:
# Saved frame : 43
# Saved frame : 86
# Saved frame : 129
# Saved frame : 172
# Saved frame : 215
# Saved frame : 258
# Saved frame : 301
# Saved frame : 344
# Saved frame : 387
# Saved frame : 430

# %%
video.release()

# %%
video.get(1)
# Out:
# 431.0

# %%
video.set(1, 0)
# Out:
# True
